# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[10,20,30,40,50]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as pl
names=["Elano Blumer","Jhon steven mendoza","jeje"]
goals=[10,20,40]
pl.plot(names,goals)
pl.show()

# %%
import matplotlib.pyplot as plt
names=["Elano Blumer","Jhon steven mendoza","jeje"]
goals=[10,20,40]
plt.plot(names,goals)
plt.title("Legends of chennayin fc")
plt.xlabel("goals scored")
plt.ylabel("goal scorer")
plt.show()
