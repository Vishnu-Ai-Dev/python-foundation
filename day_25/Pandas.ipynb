# %%
import pandas as pd
data={"Name":["A","B","C"],"Marks":[80,90,70],"Age":[18,19,18]}
df=pd.DataFrame(data)
print(df)
# Out:
#   Name  Marks  Age
# 0    A     80   18
# 1    B     90   19
# 2    C     70   18

# %%
import pandas as pd
data={"Name":["Ranpo","Dazai","Mori"],"Cases_solved":[10000,800,80],"Age":[16,19,28]}
df=pd.DataFrame(data)
print(df["Cases_solved"])
# Out:
# 0    10000
# 1      800
# 2       80
# Name: Cases_solved, dtype: int64

# %%
import pandas as pd
data={"Name":["Ranpo","Dazai","Mori"],"Cases_solved":[10000,800,80],"Age":[16,19,28]}
df=pd.DataFrame(data)
print(df["Cases_solved"].mean())
print(df["Cases_solved"]
