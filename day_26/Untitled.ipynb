# %%
import pandas as pd
data={"Name":["A","B","c","D"],"Marks":[80,70,70,85],"age":[19,19,19,19]}
df=pd.DataFrame(data)
print(df)
print(df["Marks"]>80})
print(df[["Name","Marks"]])
# Out:
#   Name  Marks  age
# 0    A     80   18
# 1    B     90   19
# 2    c     70   20
# 3    d     85   21
#   Name  Marks  age
# 1    B     90   19
# 3    d     85   21
# 0    A
# 1    B
# 2    c
# 3    d
# Name: Name, dtype: object
#   Name  Marks
# 0    A     80
# 1    B     90
# 2    c     70
# 3    d     85

# %%
import pandas as pd
data={"Name":["A","B","c","D"],"Marks":[80,70,70,85],"age":[19,19,19,19]}
df=pd.DataFrame(data)
print(df)
print(df["Marks"]>80)
print(df[["Name","Marks"]])
df["Passed"]=df["Marks"]>75
print(df)
# Out:
#   Name  Marks  age
# 0    A     80   19
# 1    B     70   19
# 2    c     70   19
# 3    D     85   19
# 0    False
# 1    False
# 2    False
# 3     True
# Name: Marks, dtype: bool
#   Name  Marks
# 0    A     80
# 1    B     70
# 2    c     70
# 3    D     85
#   Name  Marks  age  Passed
# 0    A     80   19    True
# 1    B     70   19   False
# 2    c     70   19   False
# 3    D     85   19    True

# %%
import pandas as pd
data={"Name":["A","B","c","D"],"Marks":[80,70,70,85],"age":[19,19,19,19]}
df=pd.DataFrame(data)
print(df)
print(df["Marks"]>80)
print(df[["Name","Marks"]])
print(df.sort_values("Marks"))
# Out:
#   Name  Marks  age
# 0    A     80   19
# 1    B     70   19
# 2    c     70   19
# 3    D     85   19
# 0    False
# 1    False
# 2    False
# 3     True
# Name: Marks, dtype: bool
#   Name  Marks
# 0    A     80
# 1    B     70
# 2    c     70
# 3    D     85
#   Name  Marks  age
# 1    B     70   19
# 2    c     70   19
# 0    A     80   19
# 3    D     85   19
